# %%
~Tp8Q~hxhCx2LVf8x_VdvWKzBlBMOE0NvEcLccBO

app 908e6e3d-deed-4ef0-9a04-cc30bad96e7d
tenant 3c863c9b-2221-4236-88c3-37fe9e1d06f8
nome API_fabric

##test new application and drill down permissions. what is the minimum? item.readwirteall and workspace.readwriteall? admin is required? something else?
##if approved -> detailed.

# %%
Display name:new_api_fabric
Application (client) ID:a49b035c-f602-4b26-be68-784fb7c374c9
Object ID:f44c41e5-0778-4d84-a15a-163bd6ca1f50
Directory (tenant) ID:3c863c9b-2221-4236-88c3-37fe9e1d06f8
Use8Q~przbDyulOCfaIPG6U2tOPO.bjGvtrq_a3M

# %% [markdown]
# ### Variables

# %% [markdown]
# #### Permission works

# %%
# Replace these values with your actual authentication and resource details
tenant_id = "3c863c9b-2221-4236-88c3-37fe9e1d06f8"
client_id = "908e6e3d-deed-4ef0-9a04-cc30bad96e7d"
client_secret = "~Tp8Q~hxhCx2LVf8x_VdvWKzBlBMOE0NvEcLccBO" 

resource = 'https://api.fabric.microsoft.com'
##endpoint = 'https://graph.microsoft.com/v1.0/servicePrincipals'
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 72, Finished, Available)

# %% [markdown]
# #### With minimum permissions

# %%
# Replace these values with your actual authentication and resource details
tenant_id = "3c863c9b-2221-4236-88c3-37fe9e1d06f8"
client_id = "1382bbf1-6d66-48b3-8374-b6b7173211e7"
client_secret = "Use8Q~przbDyulOCfaIPG6U2tOPO.bjGvtrq_a3M" 

resource = 'https://api.fabric.microsoft.com'
##endpoint = 'https://graph.microsoft.com/v1.0/servicePrincipals'
# Out:
# StatementMeta(, 0c718b76-347e-4fce-86b9-289b1dcb3aee, 3, Finished, Available)

# %% [markdown]
# ### get credential token

# %%
import requests
from msal import ConfidentialClientApplication


# Acquire token using MSAL
authority = f'https://login.microsoftonline.com/{tenant_id}'
app = ConfidentialClientApplication(
    client_id = client_id,
    authority=authority,
    client_credential=client_secret
)

token_response = app.acquire_token_for_client(scopes=[f'{resource}/.default'])


access_token = token_response['access_token']


# Make request to Microsoft Graph API to get service principals
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json',
    'Accept': 'application/json'
}

headers

# %% [markdown]
# ### List workspace

# %%
 
#Location: https://api.fabric.microsoft.com/v1/workspaces/cfafbeb1-8037-4d0c-896e-a46fb22287ff
url_get= f"https://api.fabric.microsoft.com/v1/workspaces/"
response_status = requests.get(url_get, headers=headers)
response_data = response_status.json()
status = response_data.get('status')

print (response_data)
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 38, Finished, Available)
# {'value': [{'id': 'f16eaf57-8b05-4d0c-9887-ffa2a083d942', 'displayName': 'My workspace', 'description': '', 'type': 'Personal'}, {'id': '937c925f-aa0c-42f0-851e-084f6a233d3c', 'displayName': 'TestLi', 'description': '', 'type': 'Workspace', 'capacityId': '7b895c97-c339-4095-a289-8dbe688e7a7b'}, {'id': 'fe183ef2-a402-4c79-8109-6a6cf9ef272e', 'displayName': 'pronto-end-to-end', 'description': '', 'type': 'Workspace', 'capacityId': '36c0ffcc-e4a5-401c-8719-3c465d225c4b'}, {'id': 'd21dfb2b-a460-4822-8724-39cef0dc18f2', 'displayName': 'WorkspaceA', 'description': '', 'type': 'Workspace', 'capacityId': 'fafdd365-bef5-4132-ba1c-5ab402d5ed0f'}, {'id': '6ddb8164-0f2f-4dad-bbab-81f0072b070b', 'displayName': 'WorkspaceB', 'description': '', 'type': 'Workspace', 'capacityId': 'fafdd365-bef5-4132-ba1c-5ab402d5ed0f'}, {'id': '15ceac20-a612-4429-ba4f-c6197e96f2c0', 'displayName': 'AI_Leme_WK', 'description': '', 'type': 'Workspace', 'capacityId': 'fafdd365-bef5-4132-ba1c-5ab402d5ed0f'}, {'id': '2c966eed-e3ed-4028-b430-2b9cdbf23d23', 'displayName': 'Workspace_dev', 'description': '', 'type': 'Workspace', 'capacityId': '36c0ffcc-e4a5-401c-8719-3c465d225c4b'}, {'id': '31dec8bc-616b-4d7e-9bbb-bc3cd1728ae5', 'displayName': 'Workspace_Stag', 'description': '', 'type': 'Workspace', 'capacityId': '36c0ffcc-e4a5-401c-8719-3c465d225c4b'}, {'id': 'dca1b780-eb7d-4403-be54-b5cdff034e60', 'displayName': 'Lemedemo_WS1', 'description': '', 'type': 'Workspace', 'capacityId': '36c0ffcc-e4a5-401c-8719-3c465d225c4b'}]}

# %% [markdown]
# ### Create workspace

# %%
from urllib.parse import urlparse

# Define the URL
url = "https://api.fabric.microsoft.com/v1/workspaces/"


jsonPayload = {
    "displayName": "Lemedemo_WS1",
    "capacityId" : "36C0FFCC-E4A5-401C-8719-3C465D225C4B"
}



# Make the POST request
response = requests.post(url,json=jsonPayload,  headers=headers)
# Check for HTTP errors
response.raise_for_status()
print (response)

if response.status_code == 200 or response.status_code == 201:
    print("Request accepted. Processing in progress.")

    
    location_header = response.headers.get("Location")
    parsed_url = urlparse(location_header)
    path_parts = parsed_url.path.split('/')
    workspace_id = path_parts[-1] 

    print (location_header)
    print(workspace_id)

    url_get= f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}"
# Out:
# StatementMeta(, 0c718b76-347e-4fce-86b9-289b1dcb3aee, 11, Finished, Available)
# <Response [201]>
# Request accepted. Processing in progress.
# https://api.fabric.microsoft.com/v1/workspaces/dca1b780-eb7d-4403-be54-b5cdff034e60
# dca1b780-eb7d-4403-be54-b5cdff034e60

# %% [markdown]
# ### Drop Workspace

# %%
import requests

workspace_id = "e9430c1e-71e0-48d9-bbde-9ad54d0b6008"

url_del = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}"

response = requests.delete(url_del, headers=headers)

if response.status_code == 200:
    print("DELETE request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# StatementMeta(, 74ac58f6-91d0-4ba9-a680-9780225a82c0, 45, Finished, Available)
# DELETE request successful.

# %% [markdown]
# ### Add permission

# %%
principal_id = "908e6e3d-deed-4ef0-9a04-cc30bad96e7d"###my user ID
workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"

##workspace_id = 

#Location: https://api.fabric.microsoft.com/v1/workspaces/cfafbeb1-8037-4d0c-896e-a46fb22287ff
url_patch= f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/roleAssignments/{principal_id}"
jsonPayload = {
  "role": "admin"
}

response_status = requests.patch(url_patch,json=jsonPayload,  headers=headers)
response_data = response_status.json()
status = response_data.get('status')

print (response_data)
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 49, Finished, Available)
# {'requestId': '2f32f1b0-475b-48e6-aeca-675413a6d661', 'errorCode': 'PrincipalWithoutWorkspaceRolePermissions', 'moreDetails': [{'relatedResource': {'resourceId': '908e6e3d-deed-4ef0-9a04-cc30bad96e7d', 'resourceType': 'Principal'}}], 'message': 'The provided principal has no role assigned in the workspace', 'relatedResource': {'resourceId': 'dca1b780-eb7d-4403-be54-b5cdff034e60', 'resourceType': 'Workspace'}}

# %% [markdown]
# ### Create Pipeline

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"


url_pipd = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/dataPipelines"

payload = {
    "displayName": "Create_Pipl_API1",
    "description": "A data pipeline created  by Rest API"
}

# Make the POST request
response = requests.post(url_pipd,json=payload,  headers=headers)
# Check for HTTP errors
response.raise_for_status()

print (response)

if response.status_code in (201,202):
    print("Post request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 51, Finished, Available)
# <Response [201]>
# Post request successful.

# %% [markdown]
# ### Delete Pipeline

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"
pipelineid= "4362c9e0-c7de-4700-b47f-c59b5fd3992"


url_pipd = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/dataPipelines/{pipelineid}"


response = requests.delete(url_pipd, headers=headers)

if response.status_code == 200:
    print("DELETE request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 54, Finished, Available)
# Error: 400 - {"requestId":"d2888b6a-5aaf-412c-a92b-ae9203f91482","errorCode":"PrincipalTypeNotSupported","message":"The operation is not supported for the principal type"}

# %% [markdown]
# ### Executing Data PIpelines

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"
pipelineid= "4362c9e0-c7de-4700-b47f-c59b5fd3992"


url_pipd = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/dataPipelines/{pipelineid}"
payload = {"executionData":{}}

response = requests.post(url_pipd, json = payload, headers=headers)
print (response)

if response.status_code in(200,201,202):
    print("Execute request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 57, Finished, Available)
# <Response [400]>
# Error: 400 - {"requestId":"d0bb2146-0ba2-462e-8132-2277cd7531c1","errorCode":"PrincipalTypeNotSupported","message":"The operation is not supported for the principal type"}

# %% [markdown]
# ### Get Data Pipeline

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"
pipelineid= "4362c9e0-c7de-4700-b47f-c59b5fd3992"


url_pipd = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/dataPipelines/{pipelineid}"

response = requests.get(url_pipd,  headers=headers)
print (response)

if response.status_code in(200,201,202):
    print("Get request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 59, Finished, Available)
# <Response [400]>
# Error: 400 - {"requestId":"0be75516-746e-46f5-879b-32aa87d1694a","errorCode":"PrincipalTypeNotSupported","message":"The operation is not supported for the principal type"}

# %% [markdown]
# ### Lakehouse

# %% [markdown]
# #### Create

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"


url_lh = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/lakehouses"

payload = {
    "displayName": "LH_API",
    "description": "A Lakehouse created  by Rest API"
}

# Make the POST request
response = requests.post(url_lh,json=payload,  headers=headers)
# Check for HTTP errors
response.raise_for_status()

print (response)

if response.status_code in (201,202):
    print("Post request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 67, Finished, Available)
# <Response [201]>
# Post request successful.

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"


url_lh = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/lakehouses"


# Make the POST request
response = requests.get(url_lh,json=payload,  headers=headers)
# Check for HTTP errors
response.raise_for_status()

print (response)

if response.status_code in (201,202):
    print("Get request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# StatementMeta(, b10fa3fa-3e6d-476b-908c-a6a12a68ff3a, 68, Finished, Available)
# <Response [200]>
# Error: 200 - {"value":[{"id":"7f4702be-455c-4da8-8927-c656b94217e6","type":"Lakehouse","displayName":"LH_API1","description":"A Lakehouse created  by Rest API","workspaceId":"dca1b780-eb7d-4403-be54-b5cdff034e60","properties":{"oneLakeTablesPath":"https://onelake.dfs.fabric.microsoft.com/dca1b780-eb7d-4403-be54-b5cdff034e60/7f4702be-455c-4da8-8927-c656b94217e6/Tables","oneLakeFilesPath":"https://onelake.dfs.fabric.microsoft.com/dca1b780-eb7d-4403-be54-b5cdff034e60/7f4702be-455c-4da8-8927-c656b94217e6/Files","sqlEndpointProperties":{"connectionString":"tm6impbbei3efcgdg77j4hig7a-qc32dxd55mbujpsuwxg76a2oma.datawarehouse.fabric.microsoft.com","id":"aa8564c0-faa4-4e89-9532-dcb6999631ca","provisioningStatus":"Success"}}},{"id":"eee65221-b222-4136-be19-e6b666bcc884","type":"Lakehouse","displayName":"LH_API","description":"A Lakehouse created  by Rest API","workspaceId":"dca1b780-eb7d-4403-be54-b5cdff034e60","properties":{"oneLakeTablesPath":"https://onelake.dfs.fabric.microsoft.com/dca1b780-eb7d-4403-be54-b5cdff034e60/eee65221-b222-4136-be19-e6b666bcc884/Tables","oneLakeFilesPath":"https://onelake.dfs.fabric.microsoft.com/dca1b780-eb7d-4403-be54-b5cdff034e60/eee65221-b222-4136-be19-e6b666bcc884/Files","sqlEndpointProperties":{"connectionString":null,"id":null,"provisioningStatus":"InProgress"}}}]}

# %% [markdown]
# #### Drop

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"
LHID = "7f4702be-455c-4da8-8927-c656b94217e6"


url_lh = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/lakehouses/{LHID}"


# Make the POST request
response = requests.delete(url_lh,  headers=headers)
# Check for HTTP errors
response.raise_for_status()

print (response)

if response.status_code in (200,201,202):
    print("delete request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")

# %% [markdown]
# ### Notebook

# %% [markdown]
# #### Create

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"


url_nb = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/notebooks"

payload = {
    "displayName": "Notebook_API1",
    "description": "A Notebook created  by Rest API"
}

# Make the POST request
response = requests.post(url_nb,json=payload,  headers=headers)
# Check for HTTP errors
response.raise_for_status()

print (response)

if response.status_code in (201,202):
    print("Post request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")

# %% [markdown]
# #### Drop

# %%
import requests

workspace_id = "dca1b780-eb7d-4403-be54-b5cdff034e60"
NBID = "92e350a4-10f9-4e7e-8134-b839010f7e1b"

url_nb = f"https://api.fabric.microsoft.com/v1/workspaces/{workspace_id}/notebooks/{NBID}"

# Make the POST request
response = requests.delete(url_nb,  headers=headers)
# Check for HTTP errors
response.raise_for_status()

print (response)

if response.status_code in (200,201,202):
    print("Delete request successful.")
else:
    print(f"Error: {response.status_code} - {response.text}")
