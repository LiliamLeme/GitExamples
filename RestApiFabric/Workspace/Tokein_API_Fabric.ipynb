# %%
#####################################################
import time
import json
import pandas as pd
from synapse.ml.mlflow import get_mlflow_env_config
import requests
from synapse.ml.fabric import FabricCredential

token = FabricCredential().get_token()
headers = dict()
headers['Authorization'] = f'Bearer {token.token}'


url_get= f"https://api.fabric.microsoft.com/v1/workspaces/"
response_status = requests.get(url_get, headers=headers)
response_data = response_status.json()
status = response_data.get('status')

print (response_data)
# Out:
# StatementMeta(, 9d907b29-c364-416e-89f8-0ded1ddc3dc9, 4, Finished, Available)
# {'value': [{'id': '4146de07-cc9c-4bb9-819e-27973d09167b', 'displayName': 'Field Demo RDL', 'description': 'Workspace for field personnel to demo RDL capabilities to customers', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '0348d075-a382-4516-ad0f-17e8dcf6989c', 'displayName': 'FTA Insights Sandbox', 'description': 'Open workspace for FastTrack for Azure employees to build and share reports.', 'type': 'Workspace'}, {'id': 'fe269e08-fbb3-4a9c-93c5-f3abcd471e7d', 'displayName': 'MESH Cost Recovery & Billing - Staging', 'description': 'MESH Cost Recovery & Billing staging site. Data is validated here before being pushed to the forward facing reporting site.', 'type': 'Workspace'}, {'id': '373e437b-0ccc-4ae8-99f8-5e0bf278a8a6', 'displayName': 'Azure EA Overage Invoicing', 'description': 'Please join SG eapbi@microsoft.com from https://idweb', 'type': 'Workspace'}, {'id': '0e0f5382-f8b0-4307-868b-5cbba7954cd7', 'displayName': 'SecurityCheck', 'description': '', 'type': 'Workspace'}, {'id': 'ecea7977-d2c6-49b5-ac02-3ec8576b3a5c', 'displayName': 'C+E Insights - Power BI', 'description': '', 'type': 'Workspace'}, {'id': '074db81b-101f-499b-a42b-855e88fbabcf', 'displayName': 'MAI_UAT_Support_WS', 'description': '', 'type': 'Workspace'}, {'id': '5bffce4c-ab71-4397-af8a-bbb306883b63', 'displayName': 'Treasury Client 360', 'description': 'Treasury Client 360', 'type': 'Workspace'}, {'id': '32419634-7759-4945-a0d5-ec36667974a4', 'displayName': '*MSX Leader Insights', 'description': '', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '40c9076d-c5e2-4b94-8b79-cb6f4589db36', 'displayName': 'Smart Reply', 'description': '', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '6fc50fbc-a047-4709-a186-d5a165d29ab2', 'displayName': 'MS Search', 'description': '', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': 'cb7c3050-75ed-41ae-82fe-fab8a435b2de', 'displayName': 'US CSA Swarm Assignments INT', 'description': '', 'type': 'Workspace'}, {'id': 'cb7bf917-9c73-4b9f-9cdb-9c90cf7b3300', 'displayName': 'US CSA Swarm Assignments Dogfood', 'description': '', 'type': 'Workspace'}, {'id': 'd78ae05a-6c0e-4b83-a89a-31315f6413c0', 'displayName': 'US CSA Swarm Assignments Production', 'description': '', 'type': 'Workspace'}, {'id': '5c6cf83d-33f8-4ad6-a15e-27d1b690334e', 'displayName': 'LMS_Channel', 'description': '', 'type': 'Workspace'}, {'id': 'efa38cce-00e7-47c7-9181-8c04c3803b61', 'displayName': 'Events', 'description': '', 'type': 'Workspace'}, {'id': 'b9d88dea-fa2b-4c22-81a2-2a7a436f5f52', 'displayName': 'CSS Ambassador Program PowerBI Hub', 'description': 'All CSS Ambassador Program PowerBI dashboards brought together under 1 workspace.', 'type': 'Workspace'}, {'id': '1cc9e205-757a-4097-9672-64ff021aec41', 'displayName': 'CCE WAN', 'description': '', 'type': 'Workspace'}, {'id': '28d98cd5-edc2-4e72-a5fa-ca18910196be', 'displayName': 'Unified Voice of the Customer (UVOC)', 'description': 'Making data-driven decisions about where to improve our products.', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '1bfae073-a2c4-4cd7-b28b-18d22c709dec', 'displayName': 'Cloud Identity POD', 'description': '', 'type': 'Workspace'}, {'id': '1f3f3900-1d0a-4bc6-9a02-91869c270e0b', 'displayName': 'IaaSExp', 'description': '', 'type': 'Workspace'}, {'id': '631f1baf-fc3e-45c4-b46c-b71fe48ad33a', 'displayName': 'O365 Problem Management', 'description': '', 'type': 'Workspace', 'capacityId': '8663e509-7165-4061-941c-8df29d00612c'}, {'id': '854f3862-6ea6-4555-8d63-751b68e09dba', 'displayName': 'MAI_Prod_ROB_WS', 'description': '', 'type': 'Workspace'}, {'id': '4ef9531e-10df-468f-a03f-05642f399c31', 'displayName': 'OPModernization', 'description': '', 'type': 'Workspace'}, {'id': 'a592a102-d7c4-46a0-a75f-8e87be172b99', 'displayName': 'BSX Signup Power BI', 'description': 'Workspace to publish BSX Signup po ...

# %%
import requests
from synapse.ml.fabric import FabricCredential

token = FabricCredential().get_token()
headers = dict()
headers['Authorization'] = f'Bearer {token.token}'


url_get= f"https://api.fabric.microsoft.com/v1/workspaces/"
response_status = requests.get(url_get, headers=headers)
response_data = response_status.json()
status = response_data.get('status')

print (response_data)
# Out:
# StatementMeta(, 9d907b29-c364-416e-89f8-0ded1ddc3dc9, 5, Finished, Available)
# {'value': [{'id': '4146de07-cc9c-4bb9-819e-27973d09167b', 'displayName': 'Field Demo RDL', 'description': 'Workspace for field personnel to demo RDL capabilities to customers', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '0348d075-a382-4516-ad0f-17e8dcf6989c', 'displayName': 'FTA Insights Sandbox', 'description': 'Open workspace for FastTrack for Azure employees to build and share reports.', 'type': 'Workspace'}, {'id': 'fe269e08-fbb3-4a9c-93c5-f3abcd471e7d', 'displayName': 'MESH Cost Recovery & Billing - Staging', 'description': 'MESH Cost Recovery & Billing staging site. Data is validated here before being pushed to the forward facing reporting site.', 'type': 'Workspace'}, {'id': '373e437b-0ccc-4ae8-99f8-5e0bf278a8a6', 'displayName': 'Azure EA Overage Invoicing', 'description': 'Please join SG eapbi@microsoft.com from https://idweb', 'type': 'Workspace'}, {'id': '0e0f5382-f8b0-4307-868b-5cbba7954cd7', 'displayName': 'SecurityCheck', 'description': '', 'type': 'Workspace'}, {'id': 'ecea7977-d2c6-49b5-ac02-3ec8576b3a5c', 'displayName': 'C+E Insights - Power BI', 'description': '', 'type': 'Workspace'}, {'id': '074db81b-101f-499b-a42b-855e88fbabcf', 'displayName': 'MAI_UAT_Support_WS', 'description': '', 'type': 'Workspace'}, {'id': '5bffce4c-ab71-4397-af8a-bbb306883b63', 'displayName': 'Treasury Client 360', 'description': 'Treasury Client 360', 'type': 'Workspace'}, {'id': '32419634-7759-4945-a0d5-ec36667974a4', 'displayName': '*MSX Leader Insights', 'description': '', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '40c9076d-c5e2-4b94-8b79-cb6f4589db36', 'displayName': 'Smart Reply', 'description': '', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '6fc50fbc-a047-4709-a186-d5a165d29ab2', 'displayName': 'MS Search', 'description': '', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': 'cb7c3050-75ed-41ae-82fe-fab8a435b2de', 'displayName': 'US CSA Swarm Assignments INT', 'description': '', 'type': 'Workspace'}, {'id': 'cb7bf917-9c73-4b9f-9cdb-9c90cf7b3300', 'displayName': 'US CSA Swarm Assignments Dogfood', 'description': '', 'type': 'Workspace'}, {'id': 'd78ae05a-6c0e-4b83-a89a-31315f6413c0', 'displayName': 'US CSA Swarm Assignments Production', 'description': '', 'type': 'Workspace'}, {'id': '5c6cf83d-33f8-4ad6-a15e-27d1b690334e', 'displayName': 'LMS_Channel', 'description': '', 'type': 'Workspace'}, {'id': 'efa38cce-00e7-47c7-9181-8c04c3803b61', 'displayName': 'Events', 'description': '', 'type': 'Workspace'}, {'id': 'b9d88dea-fa2b-4c22-81a2-2a7a436f5f52', 'displayName': 'CSS Ambassador Program PowerBI Hub', 'description': 'All CSS Ambassador Program PowerBI dashboards brought together under 1 workspace.', 'type': 'Workspace'}, {'id': '1cc9e205-757a-4097-9672-64ff021aec41', 'displayName': 'CCE WAN', 'description': '', 'type': 'Workspace'}, {'id': '28d98cd5-edc2-4e72-a5fa-ca18910196be', 'displayName': 'Unified Voice of the Customer (UVOC)', 'description': 'Making data-driven decisions about where to improve our products.', 'type': 'Workspace', 'capacityId': 'c2e774b4-5d1a-4a4c-9106-4f5b05d288ce'}, {'id': '1bfae073-a2c4-4cd7-b28b-18d22c709dec', 'displayName': 'Cloud Identity POD', 'description': '', 'type': 'Workspace'}, {'id': '1f3f3900-1d0a-4bc6-9a02-91869c270e0b', 'displayName': 'IaaSExp', 'description': '', 'type': 'Workspace'}, {'id': '631f1baf-fc3e-45c4-b46c-b71fe48ad33a', 'displayName': 'O365 Problem Management', 'description': '', 'type': 'Workspace', 'capacityId': '8663e509-7165-4061-941c-8df29d00612c'}, {'id': '854f3862-6ea6-4555-8d63-751b68e09dba', 'displayName': 'MAI_Prod_ROB_WS', 'description': '', 'type': 'Workspace'}, {'id': '4ef9531e-10df-468f-a03f-05642f399c31', 'displayName': 'OPModernization', 'description': '', 'type': 'Workspace'}, {'id': 'a592a102-d7c4-46a0-a75f-8e87be172b99', 'displayName': 'BSX Signup Power BI', 'description': 'Workspace to publish BSX Signup po ...
