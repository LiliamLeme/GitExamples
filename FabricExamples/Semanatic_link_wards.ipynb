# %%
# %pip install semantic-link
# %load_ext sempy
# Out:
# StatementMeta(, 089e3f4a-2831-4459-b72f-8abc059145dd, 16, Finished, Available)
# Collecting semantic-link
#   Downloading semantic_link-0.3.5-py3-none-any.whl (8.2 kB)
# Collecting semantic-link-functions-meteostat==0.3.5
#   Downloading semantic_link_functions_meteostat-0.3.5-py3-none-any.whl (4.5 kB)
# Collecting semantic-link-sempy==0.3.5
#   Downloading semantic_link_sempy-0.3.5-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 86.5 MB/s eta 0:00:00
# Collecting semantic-link-functions-holidays==0.3.5
#   Downloading semantic_link_functions_holidays-0.3.5-py3-none-any.whl (4.2 kB)
# Collecting semantic-link-functions-geopandas==0.3.5
#   Downloading semantic_link_functions_geopandas-0.3.5-py3-none-any.whl (4.0 kB)
# Collecting semantic-link-functions-validators==0.3.5
#   Downloading semantic_link_functions_validators-0.3.5-py3-none-any.whl (4.7 kB)
# Collecting semantic-link-functions-phonenumbers==0.3.5
#   Downloading semantic_link_functions_phonenumbers-0.3.5-py3-none-any.whl (4.3 kB)
# Collecting mapclassify
#   Downloading mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Collecting folium
#   Downloading folium-0.15.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 49.0 MB/s eta 0:00:00
# Collecting geopandas
#   Downloading geopandas-0.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 149.5 MB/s eta 0:00:00
# Collecting holidays
#   Downloading holidays-0.36-py3-none-any.whl (822 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.9/822.9 kB 149.0 MB/s eta 0:00:00
# Collecting meteostat
#   Downloading meteostat-1.6.7-py3-none-any.whl (31 kB)
# Collecting phonenumbers
#   Downloading phonenumbers-8.13.24-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 162.7 MB/s eta 0:00:00
# Collecting validators
#   Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Collecting pythonnet==3.0.1
#   Downloading pythonnet-3.0.1-py3-none-any.whl (284 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.5/284.5 kB 96.9 MB/s eta 0:00:00
# Collecting clr-loader<0.3.0,>=0.2.2
#   Downloading clr_loader-0.2.6-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 23.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from folium->semantic-link-functions-geopandas==0.3.5->semantic-link) (1.23.5)
# Collecting branca>=0.6.0
#   Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from folium->semantic-link-functions-geopandas==0.3.5->semantic-link) (3.1.2)
# Requirement already satisfied: requests in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from folium->semantic-link-functions-geopandas==0.3.5->semantic-link) (2.28.2)
# Collecting fiona>=1.8.21
#   Downloading fiona-1.9.5-cp310-cp310-manylinux2014_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 137.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=1.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from geopandas->semantic-link-functions-geopandas==0.3.5->semantic-link) (1.5.3)
# Collecting pyproj>=3.3.0
#   Downloading pyproj-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 135.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from geopandas->semantic-link-functions-geopandas==0.3.5->semantic-link) (22.0)
# Collecting shapely>=1.8.0
#   Downloading shapely-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 161.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from holidays->semantic-link-functions-holidays==0.3.5->semantic-link) (2.8.2)
# Requirement already satisfied: scipy>=1.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from mapclassify->semantic-link-functions-geopandas==0.3.5->semantic-link) (1.10.1)
# Requirement already satisfied: scikit-learn>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from mapclassify->semantic-link-functions-geopandas==0.3.5->semantic-link) (1.2.0)
# Collecting networkx>=2.7
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 175.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from meteostat->semantic-link-functions-meteostat==0.3.5->semantic-link) (2022.7.1)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from clr-loader<0.3.0,>=0.2.2->pythonnet==3.0.1->semantic-link-sempy==0.3.5->semantic-link) (1.15.1)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->semantic-link-functions-geopandas==0.3.5->semantic-link) (67.6.1)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->semantic-link-functions-geopandas==0.3.5->semantic-link) (1.16.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->semantic-link-functions-geopandas==0.3.5->semantic-link) (22.2.0)
# Requirement already satisfied: certifi in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->semantic-link-functions-geopandas==0.3.5->semantic-link) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas->semantic-link-functions-geopandas==0.3.5->semantic-link) (8.1.3)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jinja2>=2.9->folium->semantic-link-functions-geopandas==0.3.5->semantic-link) (2.1.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify->semantic-link-functions-geopandas==0.3.5->semantic-link) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.0->mapclassify->semantic-link-functions-geopandas==0.3.5->semantic-link) (3.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.3.5->semantic-link) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.3.5->semantic-link) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests->folium->semantic-link-functions-geopandas==0.3.5->semantic-link) (1.26.14)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.13->clr-loader<0.3.0,>=0.2.2->pythonnet==3.0.1->semantic-link-sempy==0.3.5->semantic-link) (2.21)
# Installing collected packages: phonenumbers, validators, shapely, pyproj, networkx, cligj, click-plugins, holidays, fiona, clr-loader, branca, pythonnet, meteostat, mapclassify, geopandas, folium, semantic-link-sempy, semantic-link-functions-validators, semantic-link-functions-phonenumbers, semantic-link-functions-meteostat, semantic-link-functions-holidays, semantic-link-functions-geopandas, semantic-link
# Successfully installed branca-0.7.0 click-plugins-1.1.1 cligj-0.7.2 clr-loader-0.2.6 fiona-1.9.5 folium-0.15.0 geopandas-0.14.0 holidays-0.36 mapclassify-2.6.1 meteostat-1.6.7 networkx-3.2.1 phonenumbers-8.13.24 pyproj-3.6.1 pythonnet-3.0.1 semantic-link-0.3.5 semantic-link-functions-geopandas-0.3.5 semantic-link-functions-holidays-0.3.5 semantic-link-functions-meteostat-0.3.5 semantic-link-functions-phonenumbers-0.3.5 semantic-link-functions-validators-0.3.5 semantic-link-sempy-0.3.5 shapely-2.0.2 validators-0.22.0
#
# [notice] A new release of pip is available: 23.0 -> 23.3.1
# [notice] To update, run: /nfs4/pyenv-b299c38a-96fd-4165-879c-a13f77adc5b9/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %%
from sempy.fabric import FabricDataFrame
from sempy.dependencies import plot_dependency_metadata
import pandas as pd


df = FabricDataFrame(pd.read_csv("/lakehouse/default/Files/Cultural_Infra/Cultural_Infra/Library/CIM 2023 Libraries.csv"))

deps = df.find_dependencies()
# Out:
# StatementMeta(, 9561ff11-109e-45d2-89a2-21993afe8867, 24, Finished, Available)

# %%
#from sempy.fabric import FabricDataFrame
#from sempy.dependencies import plot_dependency_metadata
#from sempy.samples import download_synthea
import pandas as pd
from sempy.fabric import FabricDataFrame
from sempy.dependencies import plot_dependency_metadata
from sempy.samples import download_synthea

df = FabricDataFrame(pd.read_csv("/lakehouse/default/Files/Cultural_Infra/Cultural_Infra/Library/CIM 2023 Libraries.csv"))

deps = df.find_dependencies()
plot_dependency_metadata(deps)

##https://learn.microsoft.com/en-us/fabric/data-science/semantic-link-validate-data
# Out:
# StatementMeta(, 089e3f4a-2831-4459-b72f-8abc059145dd, 19, Finished, Available)

# %%
violations = df.list_dependency_violations(determinant_col="ward_2022_name", dependent_col="ward_2022_code")
violations
# Out:
# StatementMeta(, e28cc433-2062-42e9-92bc-e267cd30beae, 16, Finished, Available)
#   ward_2022_name ward_2022_code  count
# 0       Highgate      E05013592      1
# 1       Highgate      E05013661      1
# 2  Regent's Park      E05013668      1
# 3  Regent's Park      E05013805      1

# %%
from sempy.fabric import FabricDataFrame
from sempy.dependencies import plot_dependency_metadata
from sempy.samples import download_synthea
import pandas as pd

download_synthea(which='small')

df = FabricDataFrame(pd.read_csv("/lakehouse/default/Files/Cultural_Infra/Cultural_Infra/Library/CIM 2023 Libraries.csv"))

df.plot_dependency_violations(determinant_col="ward_2022_name", dependent_col="ward_2022_code")
# Out:
# StatementMeta(, 089e3f4a-2831-4459-b72f-8abc059145dd, 21, Finished, Available)

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/" + "Files/Cultural_Infra/Cultural_Infra/Library/CIM 2023 Libraries.csv"
df = pd.read_csv("/lakehouse/default/" + "Files/Cultural_Infra/Cultural_Infra/Library/CIM 2023 Libraries.csv")
display(df)
# Out:
# StatementMeta(, ca423c82-069d-4470-841e-cbc3b544b58a, 32, Finished, Available)
# /opt/spark/python/lib/pyspark.zip/pyspark/sql/pandas/conversion.py:604: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# SynapseWidget(Synapse.DataFrame, 2c3241d5-b615-4659-92eb-39e45a3acbda)

# %%
df = spark.sql("SELECT name,latitude,longitude,easting,northing, ward_2022_name, ward_2022_code,borough_name FROM Airlift_LH.cim_2023_libraries where borough_name= 'Harrow'")
##--group by ward_2022_name, ward_2022_code,borough_name   having count(*)>1 ")
display(df)
##--ward_2022_name, ward_2022_code,borough_name 
##--name,latitude,longitude,easting,northing,
# Out:
# StatementMeta(, 089e3f4a-2831-4459-b72f-8abc059145dd, 9, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 48c891c2-3bd8-40b3-b8eb-dc34b9c699eb)
